# %%
import xarray

import matplotlib.pyplot as plt
import cartopy.crs as ccrs

# %%
bathy_file = '/Users/aponte/Current_projects/cognac/propals/amii/baie de seine/bathy_gebco/gebco_2020_n50.173379057995874_s48.94860405517183_w-2.039721447010817_e0.5888341359731002.tif'

# %%
h = xarray.open_rasterio(bathy_file)
h = h.where(h<0)

# %%
crs = ccrs.UTM('18N')

f = plt.figure(figsize=(20,10))
ax = f.add_subplot(111, projection=crs)
h.plot(ax=ax, vmax=0, vmin=-50)

# %%
xr.plot.plot

# %%
crs = ccrs.PlateCarree()

fig = plt.figure(figsize=(10,10))
ax = plt.subplot(figure=fig, projection=crs)

#fig, ax = plt.subplots(1,1, figsize=(10,10), projection=crs)
#ax = plt.subplots(projection=crs)

h.plot(ax=ax, vmax=0)
#ax.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-6f10d5927e1d> in <module>
#       2
#       3 fig = plt.figure(figsize=(10,10))
# ----> 4 ax = plt.subplot(figure=fig, projection=crs)
#       5
#       6 #fig, ax = plt.subplots(1,1, figsize=(10,10), projection=crs)
#
# ~/.miniconda3/envs/cognac/lib/python3.8/site-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1028
#    1029     fig = gcf()
# -> 1030     a = fig.add_subplot(*args, **kwargs)
#    1031     bbox = a.bbox
#    1032     byebye = []
#
# ~/.miniconda3/envs/cognac/lib/python3.8/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1385             # Axes itself allows for a 'figure' kwarg, but since we want to
#    1386             # bind the created Axes to self, it is not allowed here.
# -> 1387             raise TypeError(
# ...
